# %%
from skimage.io import imread
image = imread(r'S:\Coursera\Введение в машинное обучение\Неделя 6\Кластеризация\parrots.jpg')

# %%
import pylab
# %matplotlib inline
pylab.imshow(image)

# %%
from skimage import img_as_float

# %%
image = img_as_float(image)
image_0 = np.copy(image)

# %%
pylab.imshow(image)

# %%
image.shape
# Out:
# (474, 713, 3)

# %%
import numpy as np

# %%
r = np.array([image[:,:,0].ravel()]).T
g = np.array([image[:,:,1].ravel()]).T
b = np.array([image[:,:,2].ravel()]).T
result = np.hstack((r,g))
result = np.hstack((result,b))

# %%
result.shape
# Out:
# (337962, 3)

# %%
from sklearn.cluster import KMeans

# %%
clustersNumber = 5

# %%
model = KMeans(n_clusters=clustersNumber, init='k-means++', random_state=241)

model.fit(result)
# Out:
# KMeans(n_clusters=5, random_state=241)

# %%
w, h, d = original_shape = tuple(image.shape)
assert d == 3
image_array = np.reshape(image, (w * h, d))
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=241)
kmeans.fit(image_array)
labels = kmeans.predict(image_array)

print(10 * np.log10(1.0 / np.mean((image - image_0) ** 2)))
# Out:
# inf
# <ipython-input-42-6be7d27a2cfa>:8: RuntimeWarning: divide by zero encountered in double_scalars
#   print(10 * np.log10(1.0 / np.mean((image - image_0) ** 2)))

# %%
for cluster in range(0, clustersNumber):
    mean = np.mean(image[labels == cluster])
    image[labels == cluster] = mean
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-288128ddaed5> in <module>
#       1 for cluster in range(0, clustersNumber):
# ----> 2     mean = np.mean(image[labels == cluster])
#       3     image[labels == cluster] = mean
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 474 but corresponding boolean dimension is 337962
